# %%
class Person:
    def __init__ (self, name, age):
        self.name = name
        self.age = age
        
    def info(self):
        return f"{self.name}, {self.age} лет"
    
    # Наследование 
class Student(Person):
    def __init__ (self, name, age):
        super().__init__(name, age)
        self.__grades = [] # Инкапсуляция
        
    def add_grade (self, grade):
            if 1 <= grade <= 5:
                self.__grades.append(grade)
            else:
                print("Оценка должна быть от 1 до 5")
        
    def get_average(self):
        if self.__grades:
            return sum(self.__grades) / len(self.__grades)
        return 0
    # Полиморфизм
    def info(self):
        return f"Студент: {self.name}, {self.age} лет, Средняя оценка: {self.get_average():.2f}"
    
class Teacher(Person):
    def __init__(self, name, age, subject):
        super().__init__(name, age)
        self.subject = subject

    def info(self):
        return f"Преподаватель: {self.name}, предмет: {self.subject}"

# 📌 Работа программы
people = [
    Student("Анна", 20),
    Student("Иван", 22),
    Teacher("Петров", 45, "Математика")
]

# добавим оценки
people[0].add_grade(5)
people[0].add_grade(4)

people[1].add_grade(3)
people[1].add_grade(4)

# полиморфизм в действии
for person in people:
    print(person.info())

# %%
import os
# получить текущий путь
start_path = os.getcwd()
print(start_path) # /home/nbuser/library

os.chdir("..") # подняться на один уровень выше
os.getcwd() # '/home/nbuser'

os.chdir(start_path)
os.getcwd()

# список файлов и директорий в папке
import os

print(os.listdir()) # ['SnapchatLoader', 'FBLoader', 'tmp.py', '.gitignore', 'venv', '.git']

if 'tmp.py' not in os.listdir():
    print("Файл отсутствует в данной директории")
    
print(start_path)
print(os.path.join(start_path, 'test'))

import os

def walk_desc(path=None):
    start_path = path if path is not None else os.getcwd()

    for root, dirs, files in os.walk(start_path):
        print("Текущая директория", root)
        print("---")

        if dirs:
            print("Список папок", dirs)
        else:
            print("Папок нет")
        print("---")

        if files:
            print("Список файлов", files)
        else:
            print("Файлов нет")
        print("---")

        if files and dirs:
            print("Все пути:")
        for f in files:
            print("Файл ", os.path.join(root, f))
        for d in dirs:
            print("Папка ", os.path.join(root, d))
        print("===")

walk_desc()

f = open('path/to/file', 'filemode', encoding='utf8')

f = open('test.txt', 'w', encoding='cp1251')
f.write("This is a new string\n")


f.close()
f = open('test.txt', 'r', encoding='cp1251')
f.close()

with open("test.txt", 'rb') as f:
    a = f.read(10)
    b = f.read(23)

#f.read(3) # Error!


with open('numbers.txt', 'w', encoding='cp1251') as numbers_file:
    for i in range(1, 11):
        numbers_file.write(str(i) + '\n')

filename = 'numbers.txt'
output = 'output.txt'

with open(filename) as f:
    min_ = max_ = float(f.readline())  # считали первое число
    for line in f:
        num =  float(line)
        if num > max_:
            max_ = num
        elif num < min_:
            min_ = num

    sum_ = min_ + max_

with open(output, 'w') as f:
    f.write(str(sum_))
    f.write('\n')
    
data = """Иванов О. 4
Петров И. 3
Дмитриев Н. 2
Смирнова О. 4
Керченских В. 5
Котов Д. 2
Бирюкова Н. 1
Данилов П. 3
Аранских В. 5
Лемонов Ю. 2
Олегова К. 4"""

with open('data.txt', 'w', encoding='cp1251') as dd:
    dd.write(data)
count = 0
for line in open('data.txt'):
    points = int(line.split()[-1])
    if points < 3:
        count += 1
#print(count)

with open("data.txt", "r", encoding='cp1251') as d:
    with open("data_reverse.txt", "w") as d_reverse:
        for line in reversed(d.readlines()):
            d_reverse.write(line)
print(d_reverse)

# %%
try:
    print('Oki')
    a = 1/0
    print('Not oki?')
except ZeroDivisionError as zde:
    print(zde)
    print('Not stop?')
print('Not stop')

# %% [markdown]
# ```python
# try:
#     # ваш код
#     result = 10 / 2
# except ZeroDivisionError:
#     # код отлова
#     print("Ошибка деления на ноль!")
# else:
#     # код, который выполнится, если всё хорошо прошло в блоке try
#     print(f"Результат: {result}")
# finally:
#     # код, который выполнится по любому
#     print("Блок finally выполнен")
# ```

# %%
#

# %% [markdown]
# ```py
# age = int(input("Сколько тебе лет?"))
#
# if age > 100 or age <= 0:
#     raise ValueError("Тебе не может быть столько лет")
#
# print(f"Тебе {age} лет!") # Возраст выводится только если пользователь ввёл правильный возраст.
#
# #
# try:
#     age = int(input("Сколько тебе лет?"))
#
#     if age > 100 or age <= 0:
#         raise ValueError("Тебе не может быть столько лет")
#
#     # Возраст выводится только если пользователь ввёл правильный возраст.
#     print(f"Тебе {age} лет!")
# except ValueError:
#     print("Неправильный возраст")
# ```

# %%
def calculate_area_circle(r):
    area = pi*r**2
    return(f"{area:.3f}") #Возвращает строку
result_str = calculate_area_circle(3)
print(f"Тип f-строки: {type(result_str)}")    # <class 'str'>
###########################################
def calculate_area_circle_now(r):
    area = pi * r**2
    return round(area, 3)
result_num = calculate_area_circle_now(3)
print(f"Тип f-строки: {type(result_num)}")    # <class 'float'>
